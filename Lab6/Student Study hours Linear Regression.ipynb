# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranaam19/MSIS-AMA/blob/main/Student%20Study%20hours%20Linear%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split


#dataset
df = pd.read_csv("/content/drive/MyDrive/score.csv")

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.shape
# Out:
# (25, 2)

# %%
X = df[['Hours']]
y = df['Scores']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(f"Training data shape: {X_train.shape}, {y_train.shape}")
print(f"Testing data shape: {X_test.shape}, {y_test.shape}")
# Out:
# Training data shape: (20, 1), (20,)
# Testing data shape: (5, 1), (5,)

# %%
regressor = LinearRegression()


regressor.fit(X_train, y_train)

print("Model training complete.")
print(f"Coefficient (slope): {regressor.coef_[0]:.2f}")
print(f"Intercept: {regressor.intercept_:.2f}")
# Out:
# Model training complete.
# Coefficient (slope): 9.91
# Intercept: 2.02

# %%
y_pred = regressor.predict(X_test)

mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Mean Squared Error (MSE): 21.60
# Root Mean Squared Error (RMSE): 4.65

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Hours', y='Scores', data=df, s=100, color='blue', label='Actual Scores')
plt.plot(X_train, regressor.predict(X_train), color='red', linewidth=2, label='Regression Line (Trained)')
plt.title('Hours vs. Scores with Linear Regression Line')
plt.xlabel('Study Hours')
plt.ylabel('Percentage Score')
plt.grid(True)
plt.legend()
plt.show()

# %%
input_hours = 9.25


predicted_score = regressor.predict([[input_hours]])

print(f"If a student studies for {input_hours} hours, they are predicted to score approximately {predicted_score[0]:.2f}%")
# Out:
# If a student studies for 9.25 hours, they are predicted to score approximately 93.69%
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
